# %%
import yfinance as yf
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tickers = [ 'GLD', 'BOTZ', 'BTC-USD', 'MXI', 'SPY', 'TNXP', 'UCC', 'VMI', '^VIX']
prices = yf.download(tickers, start = '2015-01-01', end = '2025-08-30', auto_adjust = False, multi_level_index = False)['Adj Close']
prices.head()
# Out:
# [*********************100%***********************]  9 of 9 completed
# Ticker      BOTZ     BTC-USD         GLD        MXI         SPY          TNXP  \
# Date
# 2015-01-01   NaN  314.248993         NaN        NaN         NaN           NaN
# 2015-01-02   NaN  315.032013  114.080002  41.985657  171.567978  3.788800e+09
# 2015-01-03   NaN  281.082001         NaN        NaN         NaN           NaN
# 2015-01-04   NaN  264.195007         NaN        NaN         NaN           NaN
# 2015-01-05   NaN  274.473999  115.800003  40.878990  168.469589  3.744000e+09
#
# Ticker            UCC         VMI       ^VIX
# Date
# 2015-01-01        NaN         NaN        NaN
# 2015-01-02  11.943197  113.824425  17.790001
# 2015-01-03        NaN         NaN        NaN
# 2015-01-04        NaN         NaN        NaN
# 2015-01-05  11.483608  111.999977  19.920000

# %%
msno.matrix(prices)
# Out:
# <Axes: >

# %%
prices = prices.dropna(axis = 0, how = 'any')
msno.matrix(prices)
# Out:
# <Axes: >
